# %%
# Set Variables
SW_LAT = -38.88917
SW_LON = 140.84444
NE_LAT = -33.70833
NE_LON = 150.0

PARAMETER_NAME = "Pat1_C_B_1_DailyMean"
PROPERTY_NAME = "Electrical Conductivity @ 25C"
TIME_PERIOD = "2010/2024"

# %%
import requests
from xml.etree.ElementTree import Element, SubElement, tostring

# Define the namespace map to use in the XML
ns = {
    'sos': "http://www.opengis.net/sos/2.0",
    'fes': "http://www.opengis.net/fes/2.0",
    'gml': "http://www.opengis.net/gml/3.2",
    'xsi': "http://www.w3.org/2001/XMLSchema-instance",
    'sams': "http://www.opengis.net/samplingSpatial/2.0"
}

# Define the endpoint URL for the SOS service
url = "http://www.bom.gov.au/waterdata/services"

# Create XML elements for the request
envelope = Element('sos:GetFeatureOfInterest', {
    'service': 'SOS', 'version': '2.0', 'xmlns:sos': ns['sos'], 'xmlns:fes': ns['fes'], 'xmlns:gml': ns['gml'], 'xmlns:xsi': ns['xsi'], 'xmlns:sams': ns['sams']
})

spatial_filter = SubElement(envelope, 'sos:spatialFilter')
bbox = SubElement(spatial_filter, 'fes:BBOX')
value_ref = SubElement(bbox, 'fes:ValueReference')
value_ref.text = 'om:featureOfInterest/*/sams:shape'

envelope_ = SubElement(bbox, 'gml:Envelope', {
    'srsName': 'urn:ogc:def:crs:EPSG::4326'
})
lower_corner = SubElement(envelope_, 'gml:lowerCorner')
upper_corner = SubElement(envelope_, 'gml:upperCorner')

# Insert the actual coordinates for the Murray River bounding box
lower_corner.text = f"{SW_LAT} {SW_LON}"  # Southernmost, westernmost
upper_corner.text = f"{NE_LAT} {NE_LON}"  # Northernmost, easternmost

# Add observed property element
observed_property = SubElement(envelope, 'sos:observedProperty')
observed_property.text = f"http://bom.gov.au/waterdata/services/parameters/{PROPERTY_NAME}"  # Example observed property


# Convert the ElementTree to a string
request_xml = tostring(envelope, 'utf-8')

# Define headers for the POST request
headers = {
    'Content-Type': 'application/xml'
}

# Send the POST request
FeatureOfInterestResponse = requests.post(url, data=request_xml, headers=headers)

# Print the response from the server

# %%
import requests
import xml.etree.ElementTree as ET
# Sample XML response from GetFeatureOfInterest
xml_response = FeatureOfInterestResponse.text

# Parse the XML string
root = ET.fromstring(xml_response)

# Extract station IDs
station_ids = [elem.text.split('/')[-1] for elem in root.findall('.//gml:identifier', namespaces={'gml': 'http://www.opengis.net/gml/3.2'})]

print(station_ids) 

#get stations within region
# Out:
# ['WYS00BSN', '41200209', '412028', '410061', '41000271', '235222', '235260', '235277', '217006', 'WARMUZ01', 'WAREUV01', 'WARMWEIR', 'WARWUV01', '408202', '408203', '408209', '408200', '415220', '410171', '410091', '410186', '410170', '412169', '406753', '406744', '406750', '406751', '406758', '409111', '407252', '410167', '233217', '233218', '233224', '233200', '233247', '233269', '233201', '415224', '219026', '219003', '41010904', '410012', '410134', '410168', '410182', '410183', '410097', '233211', 'WBITTEAO', 'WBITBASO', 'WBITTWEO', '412103', '412171', '409080', 'WBMRCANN', 'WBMRBESS', 'WBMRGARF', 'WBMRPAKN', 'WBMRTYNG', '225248', '412029', '233228', '409090', '409085', 'WBRAHAMS', '41000270', '219025', '404216', '404224', '404214', '414728', '409075', 'WBULLKFR', 'WBUNDIVW', 'WBUNTTPD', 'WBUNRDSD', 'WBUNRUSD', 'WBUNWEIR', '412170', '409113', '410717', 'GW088184.1.1', '340013', '410774', '406202', '406265', '406219', '406213', '406766', '406764', '421179', '221224', 'WCARCKDS', 'WCARCKUS', 'WCADNT15', 'WCADNT58', 'WCADNT40', 'WCADNT35', 'WCADNT30', 'WCADNT25', 'WCADNT20', 'WCADNT10', 'WCADNT05', 'WCADNT00', 'WCADBOTT', 'WCADNT55', 'WCADNT50', 'WCADNT60', 'WCADNT65', 'WCADNT70', 'WCADRE01', 'WCARTPOL', 'WTHOMCAC', '405246', '410191', 'WCMEUZ01', 'WCMWAV01', '41310026', '41010233', '410135', '410133', '406215', '41310022', '410157', '415237', 'WCONDR22', 'WCONTR22', '410081', 'WCORAV01', 'WCORIF01', '412050', '41200208', '410163', '412154', '410092', '41310028', 'A4261224', 'A4260535', 'A4261091', 'A4261107', '410733', '570946', '410730', '340000', '410747', '410110', '410108', '425011', '425007', '425017', '237205', '410172', '409053', '409082', '409081', '406704', '230232', 'WDEEPR07', 'WDEEPR9B', 'WDEEPR09', '222008', '409083', 'WDEVIL10', 'WDEVIL05', 'WDEVBOTT', 'WDEVBEN0', 'WDEVBENO', 'WDEVIL00', 'WDONAV01', 'WSWINDSW', 'WDRORESI', 'WDRORES2', 'WDRORESO', '238220', '409003', '409035', '409014', '409008', '409047', '409023', '409029', 'WETTGR22', '222028', '409077', '414702', '410148', 'WFRANA05', 'AAANBOTT', 'WFRANA00', 'WFRANK05', 'WFRANBOT', 'WFSTRESO', 'WFRANK00', 'A4260635', '410750', 'WGARBASI', '235224', '215237', '215237B', '410106', '238202', '238210', '238206', '238224', '415258', '410057', '410024', '405232', '405200', '405201', 'WGOLBYPS', '405259', 'WGRCAV01', 'WGRCCUSW', '238219', 'WGVLRI01', 'WGVLNT15', 'WGVLNT05', 'WGVLNT00', 'WGVLBOTT', 'WGVLNT10', 'WGVLNT30', 'WGVLNT25', 'WGVLNT20', 'WGVLRE01', 'WOSGLYR9', '410751', '410731', '410043', '404207', '236209', '236202', '410103', '412175', '410790', '401013', 'WJORSWIL', 'WJORUSSW', 'WJORAG01', 'WJORUJ21', '410025', '235211', '402205', '402205A', '402222', '402223', '414723', '410156', '410048', '226033', '226027', '412194', '412005', '412045', '412065', '412088', '412027', '412067', '412002', '412149', '404219', '226041', '226227', 'WTHOMLBC', '407712', '407202', '407203', '407229', '409044', '4261093', 'A4261093', 'A4260553', '410776', '410746', '410761', '410777', '409712', '410068', '410004', '41000272', '410050', '410023', '410008', '410130', '410001', '410195', '401019', '401008', '401017', '401026', '401009', 'WMAQUSET', 'WMAQUS11', 'WMAQUO01', 'WMARNT08', 'WMARNT20', 'WMARNT25', 'WMARNT05', 'WMARNT00', 'WMARBOTT', 'WMARNT15', 'WMARNT10', 'WMARNT30', 'WMATHR22', '41310024', '41310023', 'WMHNUV01', '414706', '41310027', '409036', '410141', '410165', '410085', '224217', '401211', '401203', '401204', '401204A', 'WSILEM41', '215007', '232210', '232204', 'WMORLR04', 'WMORNROL', '406756', 'WMOSQR03', '406224', '215209', '222027', '404712', '404713', 'WMUDCKTD', '401020', '406263', '409001', '409215', '401012', '401549', '414207', '409002', '409017', '414203', '409016', '409037', '401201', '413001', '413002', '414206', '414205', '409204', '409202', '409207B', '409025', '409202A', '414200', '414201', '409005', '409006', '409215B', '2122711', '410044', 'WMYRTR22', '410729', 'A4260576', 'A4261063', 'A2391076', '41001702', '414724', '414721', '219016', '223210', ...

# %%
import requests
from xml.etree import ElementTree as ET
import pandas as pd

# Define the SOS2 endpoint URL
url = "http://www.bom.gov.au/waterdata/services"

data = []  # List to store data for DataFrame


# Define the parameters for the GetObservation request
params = {
    'service': 'SOS',
    'version': '2.0.0',
    'request': 'GetObservation',
    'procedure': f"http://bom.gov.au/waterdata/services/tstypes/{PARAMETER_NAME}",
    'observedProperty': f"http://bom.gov.au/waterdata/services/parameters/{PROPERTY_NAME}",
    'temporalFilter': f"om:phenomenonTime,{TIME_PERIOD}"
}

# Assuming station_ids is defined earlier in the script
for station_id in station_ids:
    print(f"Querying data for station: {station_id}")
    
    # Add the station ID to the parameters
    params['featureOfInterest'] = f"http://bom.gov.au/waterdata/services/stations/{station_id}"
    
    # Make the GetObservation request to the SOS2 endpoint
    response = requests.get(url, params=params, timeout=100)  # Added timeout
    
    if response.status_code == 200:
        # Parse the XML response
        root = ET.fromstring(response.content)
        
        # Find all the MeasurementTVP elements which contain the time-value pairs
        tvp_elements = root.findall('.//{http://www.opengis.net/waterml/2.0}MeasurementTVP')
        
        if not tvp_elements:
            print("No data found for this station.")
        else:
            # Print out the time and value for each MeasurementTVP
            for tvp in tvp_elements:
                time = tvp.find('{http://www.opengis.net/waterml/2.0}time').text
                value = tvp.find('{http://www.opengis.net/waterml/2.0}value').text
                #print(f"  {time}: {value}")
                data.append({'Station': station_id, 'Time': time, 'Value': value})
    else:
        print(f"Failed to retrieve data for station {station_id}. HTTP status code: {response.status_code}")
        print("Response Headers:", response.headers)
        print("Response Body:", response.text)


df = pd.DataFrame(data)

pivot_df = df.pivot_table(index='Time', values='Value', columns='Station', aggfunc='first')

# Show pivoted DataFrame
print(pivot_df)
# Show DataFrame
# Out:
# Querying data for station: WYS00BSN
# No data found for this station.
# Querying data for station: 41200209
# Querying data for station: 412028
# Querying data for station: 410061
# Querying data for station: 41000271
# Querying data for station: 235222
# Querying data for station: 235260
# Querying data for station: 235277
# Querying data for station: 217006
# Querying data for station: WARMUZ01
# No data found for this station.
# Querying data for station: WAREUV01
# No data found for this station.
# Querying data for station: WARMWEIR
# Querying data for station: WARWUV01
# No data found for this station.
# Querying data for station: 408202
# Querying data for station: 408203
# Querying data for station: 408209
# Querying data for station: 408200
# Querying data for station: 415220
# Querying data for station: 410171
# No data found for this station.
# Querying data for station: 410091
# Querying data for station: 410186
# Querying data for station: 410170
# Querying data for station: 412169
# No data found for this station.
# Querying data for station: 406753
# Querying data for station: 406744
# Querying data for station: 406750
# Querying data for station: 406751
# Querying data for station: 406758
# Querying data for station: 409111
# Querying data for station: 407252
# Querying data for station: 410167
# No data found for this station.
# Querying data for station: 233217
# Querying data for station: 233218
# Querying data for station: 233224
# Querying data for station: 233200
# Querying data for station: 233247
# Querying data for station: 233269
# Querying data for station: 233201
# Querying data for station: 415224
# No data found for this station.
# Querying data for station: 219026
# No data found for this station.
# Querying data for station: 219003
# Querying data for station: 41010904
# Querying data for station: 410012
# Querying data for station: 410134
# Querying data for station: 410168
# Querying data for station: 410182
# Querying data for station: 410183
# Querying data for station: 410097
# Querying data for station: 233211
# Querying data for station: WBITTEAO
# No data found for this station.
# Querying data for station: WBITBASO
# No data found for this station.
# Querying data for station: WBITTWEO
# No data found for this station.
# Querying data for station: 412103
# No data found for this station.
# Querying data for station: 412171
# No data found for this station.
# Querying data for station: 409080
# No data found for this station.
# Querying data for station: WBMRCANN
# No data found for this station.
# Querying data for station: WBMRBESS
# No data found for this station.
# Querying data for station: WBMRGARF
# No data found for this station.
# Querying data for station: WBMRPAKN
# No data found for this station.
# Querying data for station: WBMRTYNG
# No data found for this station.
# Querying data for station: 225248
# Querying data for station: 412029
# Querying data for station: 233228
# Querying data for station: 409090
# No data found for this station.
# Querying data for station: 409085
# No data found for this station.
# Querying data for station: WBRAHAMS
# No data found for this station.
# Querying data for station: 41000270
# Querying data for station: 219025
# Querying data for station: 404216
# Querying data for station: 404224
# Querying data for station: 404214
# Querying data for station: 414728
# Querying data for station: 409075
# Querying data for station: WBULLKFR
# No data found for this station.
# Querying data for station: WBUNDIVW
# No data found for this station.
# Querying data for station: WBUNTTPD
# No data found for this station.
# Querying data for station: WBUNRDSD
# No data found for this station.
# Querying data for station: WBUNRUSD
# No data found for this station.
# Querying data for station: WBUNWEIR
# No data found for this station.
# Querying data for station: 412170
# No data found for this station.
# Querying data for station: 409113
# Querying data for station: 410717
# No data found for this station.
# Querying data for station: GW088184.1.1
# Querying data for station: 340013
# Querying data for station: 410774
# Querying data for station: 406202
# Querying data for station: 406265
# Querying data for station: 406219
# Querying data for station: 406213
# Querying data for station: 406766
# Querying data for station: 406764
# Querying data for station: 421179
# No data found for this station.
# Querying data for station: 221224
# Querying data for station: WCARCKDS
# No data found for this station.
# Querying data for station: WCARCKUS
# No data found for this station.
# Querying data for station: WCADNT15
# No data found for this station.
# Querying data for station: WCADNT58
# No data found for this station.
# Querying data for station: WCADNT40
# No data found for this station.
# Querying data for station: WCADNT35
# No data found for this station.
# Querying data for station: WCADNT30
# Querying data for station: WCADNT25
# No data found for this station.
# Querying data for station: WCADNT20
# No data found for this station.
# Querying data for station: WCADNT10
# Querying data for station: WCADNT05
# No data found for this station.
# Querying data for station: WCADNT00
# Querying data for station: WCADBOTT
# Querying data for station: WCADNT55
# No data found for this station.
# Querying data for station: WCADNT50
# No data found for this station.
# Querying data for station: WCADNT60
# No data found for this station.
# Querying data for station: WCADNT65
# No data found for this station.
# Querying data for station: WCADNT70
# No data found for this station.
# Querying data for station: WCADRE01
# Querying data for station: WCARTPOL
# No data found for this station.
# Querying data for station: WTHOMCAC
# No data found for this station.
# Querying data for station: 405246
# Querying data for station: 410191
# Querying data for station: WCMEUZ01
# No data found for this station.
# Querying data for station: WCMWAV01
# No data found for this station.
# Querying data for station: 41310026
# Querying data for station: 41010233
# No data found for this station.
# Querying data for station: 410135
# No data found for this station.
# Querying data for station: 410133
# Querying data for station: 406215
# Querying data for station: 41310022
# Querying data for station: 410157
# No data found for this station.
# Querying data for station: 415237
# Querying data for station: WCONDR22
# No data found for this station.
# Querying data for station: WCONTR22
# No data found for this station.
# Querying data for station: 410081
# Querying data for station: WCORAV01
# No data found for this station.
# Querying data for station: WCORIF01
# Querying data for station: 412050
# No data found for this station.
# Querying data for station: 41200208
# Querying data for station: 410163
# No data found for this station.
# Querying data for station: 412154
# Querying data for station: 410092
# Querying data for station: 41310028
# Querying data for station: A4261224
# Querying data for station: A4260535
# No data found for this station.
# Querying data for station: A4261091
# Querying data for station: A4261107
# Querying data for station: 410733
# Querying data for station: 570946
# Querying data for station: 410730
# Querying data for station: 340000
# Querying data for station: 410747
# Querying data for station: 410110
# Querying data for station: 410108
# Querying data for station: 425011
# Querying data for station: 425007
# Querying data for station: 425017
# No data found for this station.
# Querying data for station: 237205
# Querying data for station: 410172
# No data found for this station.
# Querying data for station: 409053
# No data found for this station.
# Querying data for station: 409082
# No data found for this station.
# Querying data for station: 409081
# No data found for this station.
# Querying data for station: 406704
# Querying data for station: 230232
# No data found for this station.
# Querying data for station: WDEEPR07
# No data found for this station.
# Querying data for station: WDEEPR9B
# No data found for this station.
# Querying data for station: WDEEPR09
# No data found for this station.
# Querying data for station: 222008
# Querying data for station: 409083
# No data found for this station.
# Querying data for station: WDEVIL10
# No data found for this station.
# Querying data for station: WDEVIL05
# No data found for this station.
# Querying data for station: WDEVBOTT
# No data found for this station.
# Querying data for station: WDEVBEN0
# No data found for this station.
# Querying data for station: WDEVBENO
# No data found for this station.
# Querying data for station: WDEVIL00
# No data found for this station.
# Querying data for station: WDONAV01
# Querying data for station: WSWINDSW
# No data found for this station.
# Querying data for station: WDRORESI
# No data found for this station.
# Querying data for station: WDRORES2
# No data found for this station.
# Querying data for station: WDRORESO
# No data found for this station.
# Querying data for station: 238220
# Querying data for station: 409003
# Querying data for station: 409035
# Querying data for station: 409014
# Querying data for station: 409008
# Querying data for station: 409047
# Querying data for station: 409023
# Querying data for station: 409029
# Querying data for station: WETTGR22
# No data found for this station.
# Querying data for station: 222028
# Querying data for station: 409077
# No data found for this station.
# Querying data for station: 414702
# Querying data for station: 410148
# Querying data for station: WFRANA05
# No data found for this station.
# Querying data for station: AAANBOTT
# No data found for this station.
# Querying data for station: WFRANA00
# No data found for this station.
# Querying data for station: WFRANK05
# No data found for this station.
# Querying data for station: WFRANBOT
# No data found for this station.
# Querying data for station: WFSTRESO
# No data found for this station.
# Querying data for station: WFRANK00
# Querying data for station: A4260635
# Querying data for station: 410750
# Querying data for station: WGARBASI
# No data found for this station.
# Querying data for station: 235224
# Querying data for station: 215237
# Querying data for station: 215237B
# Querying data for station: 410106
# Querying data for station: 238202
# Querying data for station: 238210
# Querying data for station: 238206
# Querying data for station: 238224
# Querying data for station: 415258
# No data found for this station.
# Querying data for station: 410057
# Querying data for station: 410024
# Querying data for station: 405232
# Querying data for station: 405200
# Querying data for station: 405201
# Querying data for station: WGOLBYPS
# No data found for this station.
# Querying data for station: 405259
# Querying data for station: WGRCAV01
# Querying data for station: WGRCCUSW
# Querying data for station: 238219
# Querying data for station: WGVLRI01
# No data found for this station.
# Querying data for station: WGVLNT15
# No data found for this station.
# Querying data for station: WGVLNT05
# No data found for this station.
# Querying data for station: WGVLNT00
# Querying data for station: WGVLBOTT
# Querying data for station: WGVLNT10
# Querying data for station: WGVLNT30
# No data found for this station.
# Querying data for station: WGVLNT25
# No data found for this station.
# Querying data for station: WGVLNT20
# No data found for this station.
# Querying data for station: WGVLRE01
# Querying data for station: WOSGLYR9
# No data found for this station.
# Querying data for station: 410751
# Querying data for station: 410731
# Querying data for station: 410043
# Querying data for station: 404207
# No data found for this station.
# Querying data for station: 236209
# Querying data for station: 236202
# Querying data for station: 410103
# Querying data for station: 412175
# Querying data for station: 410790
# Querying data for station: 401013
# Querying data for station: WJORSWIL
# No data found for this station.
# Querying data for station: WJORUSSW
# No data found for this station.
# Querying data for station: WJORAG01
# No data found for this station.
# Querying data for station: WJORUJ21
# No data found for this station.
# Querying data for station: 410025
# Querying data for station: 235211
# Querying data for station: 402205
# Querying data for station: 402205A
# Querying data for station: 402222
# Querying data for station: 402223
# No data found for this station.
# Querying data for station: 414723
# Querying data for station: 410156
# Querying data for station: 410048
# Querying data for station: 226033
# Querying data for station: 226027
# Querying data for station: 412194
# Querying data for station: 412005
# Querying data for station: 412045
# No data found for this station.
# Querying data for station: 412065
# No data found for this station.
# Querying data for station: 412088
# No data found for this station.
# Querying data for station: 412027
# Querying data for station: 412067
# Querying data for station: 412002
# Querying data for station: 412149
# No data found for this station.
# Querying data for station: 404219
# No data found for this station.
# Querying data for station: 226041
# Querying data for station: 226227
# Querying data for station: WTHOMLBC
# No data found for this station.
# Querying data for station: 407712
# Querying data for station: 407202
# Querying data for station: 407203
# Querying data for station: 407229
# Querying data for station: 409044
# Querying data for station: 4261093
# Querying data for station: A4261093
# Querying data for station: A4260553
# Querying data for station: 410776
# No data found for this station.
# Querying data for station: 410746
# Querying data for station: 410761
# Querying data for station: 410777
# Querying data for station: 409712
# Querying data for station: 410068
# Querying data for station: 410004
# Querying data for station: 41000272
# Querying data for station: 410050
# Querying data for station: 410023
# Querying data for station: 410008
# Querying data for station: 410130
# Querying data for station: 410001
# Querying data for station: 410195
# Querying data for station: 401019
# No data found for this station.
# Querying data for station: 401008
# Querying data for station: 401017
# Querying data for station: 401026
# Querying data for station: 401009
# Querying data for station: WMAQUSET
# Querying data for station: WMAQUS11
# Querying data for station: WMAQUO01
# No data found for this station.
# Querying data for station: WMARNT08
# No data found for this station.
# Querying data for station: WMARNT20
# No data found for this station.
# Querying data for station: WMARNT25
# No data found for this station.
# Querying data for station: WMARNT05
# No data found for this station.
# Querying data for station: WMARNT00
# Querying data for station: WMARBOTT
# Querying data for station: WMARNT15
# No data found for this station.
# Querying data for station: WMARNT10
# Querying data for station: WMARNT30
# No data found for this station.
# Querying data for station: WMATHR22
# No data found for this station.
# Querying data for station: 41310024
# Querying data for station: 41310023
# Querying data for station: WMHNUV01
# No data found for this station.
# Querying data for station: 414706
# Querying data for station: 41310027
# Querying data for station: 409036
# Querying data for station: 410141
# Querying data for station: 410165
# No data found for this station.
# Querying data for station: 410085
# No data found for this station.
# Querying data for station: 224217
# Querying data for station: 401211
# Querying data for station: 401203
# Querying data for station: 401204
# Querying data for station: 401204A
# Querying data for station: WSILEM41
# No data found for this station.
# Querying data for station: 215007
# No data found for this station.
# Querying data for station: 232210
# Querying data for station: 232204
# Querying data for station: WMORLR04
# No data found for this station.
# Querying data for station: WMORNROL
# No data found for this station.
# Querying data for station: 406756
# Querying data for station: WMOSQR03
# No data found for this station.
# Querying data for station: 406224
# Querying data for station: 215209
# Querying data for station: 222027
# Querying data for station: 404712
# Querying data for station: 404713
# Querying data for station: WMUDCKTD
# No data found for this station.
# Querying data for station: 401020
# Querying data for station: 406263
# Querying data for station: 409001
# Querying data for station: 409215
# Querying data for station: 401012
# Querying data for station: 401549
# Querying data for station: 414207
# Querying data for station: 409002
# Querying data for station: 409017
# Querying data for station: 414203
# Querying data for station: 409016
# Querying data for station: 409037
# Querying data for station: 401201
# Querying data for station: 413001
# Querying data for station: 413002
# Querying data for station: 414206
# No data found for this station.
# Querying data for station: 414205
# No data found for this station.
# Querying data for station: 409204
# Querying data for station: 409202
# Querying data for station: 409207B
# Querying data for station: 409025
# Querying data for station: 409202A
# Querying data for station: 414200
# Querying data for station: 414201
# Querying data for station: 409005
# Querying data for station: 409006
# Querying data for station: 409215B
# Querying data for station: 2122711
# Querying data for station: 410044
# Querying data for station: WMYRTR22
# No data found for this station.
# Querying data for station: 410729
# Querying data for station: A4260576
# No data found for this station.
# Querying data for station: A4261063
# No data found for this station.
# Querying data for station: A2391076
# Querying data for station: 41001702
# Querying data for station: 414724
# Querying data for station: 414721
# Querying data for station: 219016
# Querying data for station: 223210
# Querying data for station: 409086
# Querying data for station: 409046
# No data found for this station.
# Querying data for station: 409048
# Querying data for station: 410164
# No data found for this station.
# Querying data for station: 410185
# Querying data for station: 223218
# Querying data for station: 41001701
# Querying data for station: WOSHER01
# Querying data for station: WOSHEV01
# No data found for this station.
# Querying data for station: WOSRDSB1
# No data found for this station.
# Querying data for station: WOSHRCBT
# Querying data for station: WOSHRC00
# Querying data for station: WOSRIR01
# Querying data for station: WOSRBR09
# No data found for this station.
# Querying data for station: WOSQUI01
# Querying data for station: WOSQIR01
# No data found for this station.
# Querying data for station: 410093
# Querying data for station: WOLICKDS
# No data found for this station.
# Querying data for station: WOLICKUS
# No data found for this station.
# Querying data for station: 403241
# Querying data for station: WPAKBASI
# No data found for this station.
# Querying data for station: WPAKBASO
# No data found for this station.
# Querying data for station: 220003
# No data found for this station.
# Querying data for station: 231234
# No data found for this station.
# Querying data for station: WPEDWEIR
# No data found for this station.
# Querying data for station: 410713
# Querying data for station: 410853
# Querying data for station: A4260595
# Querying data for station: A4260580
# Querying data for station: 410781
# Querying data for station: 414703
# Querying data for station: 41310025
# Querying data for station: 233260
# No data found for this station.
# Querying data for station: 404210
# Querying data for station: 415259
# Querying data for station: 415257
# Querying data for station: 414717
# Querying data for station: 414716
# Querying data for station: 405720
# Querying data for station: 2122518
# Querying data for station: A4261791
# Querying data for station: A4250010
# Querying data for station: A4260510
# Querying data for station: A4260509
# Querying data for station: A4260508
# Querying data for station: A4260506
# Querying data for station: A4260501
# Querying data for station: A4260653
# No data found for this station.
# Querying data for station: A4260704
# Querying data for station: A4260200
# Querying data for station: A4260705
# Querying data for station: A4261022
# Querying data for station: A4260641
# Querying data for station: A4261059
# Querying data for station: A4260701
# Querying data for station: A4261051
# Querying data for station: A4260502
# Querying data for station: 235276
# Querying data for station: WSAWPR22
# No data found for this station.
# Querying data for station: 235237
# Querying data for station: 405234
# No data found for this station.
# Querying data for station: 405779
# Querying data for station: 405758
# Querying data for station: 215208
# Querying data for station: WSILEM42
# No data found for this station.
# Querying data for station: WSILEM11
# Querying data for station: WSILEM21
# Querying data for station: WSILNT15
# No data found for this station.
# Querying data for station: WSILNT05
# No data found for this station.
# Querying data for station: WSILNT08
# No data found for this station.
# Querying data for station: WSILCD05
# No data found for this station.
# Querying data for station: WSILS220
# No data found for this station.
# Querying data for station: WSILS210
# No data found for this station.
# Querying data for station: WSILS205
# No data found for this station.
# Querying data for station: WSILS200
# No data found for this station.
# Querying data for station: WSILS215
# No data found for this station.
# Querying data for station: WSILBOTT
# Querying data for station: WSILCD00
# No data found for this station.
# Querying data for station: WSILNT25
# No data found for this station.
# Querying data for station: WSILNT20
# No data found for this station.
# Querying data for station: WSILNT10
# Querying data for station: WSILNT00
# Querying data for station: WSILNT30
# No data found for this station.
# Querying data for station: WSILYS00
# No data found for this station.
# Querying data for station: WSILYS10
# No data found for this station.
# Querying data for station: WSILYS05
# No data found for this station.
# Querying data for station: WSILYV05
# No data found for this station.
# Querying data for station: WSILYV00
# No data found for this station.
# Querying data for station: WSILOI05
# No data found for this station.
# Querying data for station: WSILOI10
# No data found for this station.
# Querying data for station: WSILOI15
# No data found for this station.
# Querying data for station: WSILOI00
# No data found for this station.
# Querying data for station: WSILTPOL
# No data found for this station.
# Querying data for station: WSILEM31
# Querying data for station: WSLVRCK1
# Querying data for station: 410184
# Querying data for station: WSMTHR03
# No data found for this station.
# Querying data for station: 222013
# Querying data for station: 222026
# Querying data for station: 222203
# Querying data for station: 222021
# Querying data for station: 222201
# Querying data for station: 222023
# Querying data for station: WSTVUV01
# No data found for this station.
# Querying data for station: 405240
# Querying data for station: WSUGAW11
# No data found for this station.
# Querying data for station: WSCKWSTR
# No data found for this station.
# Querying data for station: WSUGNW80
# No data found for this station.
# Querying data for station: WSUGNW25
# No data found for this station.
# Querying data for station: WSUGNW30
# Querying data for station: WSUGNW35
# No data found for this station.
# Querying data for station: WSUGNW40
# No data found for this station.
# Querying data for station: WSUGNW45
# No data found for this station.
# Querying data for station: WSUGNW50
# Querying data for station: WSUGNW60
# No data found for this station.
# Querying data for station: WSUGNW70
# No data found for this station.
# Querying data for station: WSUGNW75
# No data found for this station.
# Querying data for station: WSUGNW20
# No data found for this station.
# Querying data for station: WSUGNW15
# No data found for this station.
# Querying data for station: WSUGNW10
# Querying data for station: WSUGNW00
# Querying data for station: WSUGNW05
# No data found for this station.
# Querying data for station: WSUGBOTT
# Querying data for station: WSUGNE00
# No data found for this station.
# Querying data for station: WSUGNBR1
# No data found for this station.
# Querying data for station: WSUGNE40
# No data found for this station.
# Querying data for station: WSUGNE45
# No data found for this station.
# Querying data for station: WSUGNE50
# No data found for this station.
# Querying data for station: WSUGNE55
# No data found for this station.
# Querying data for station: WSUGNE60
# No data found for this station.
# Querying data for station: WSUGNE65
# No data found for this station.
# Querying data for station: WSUGNE05
# No data found for this station.
# Querying data for station: WSUGNE10
# No data found for this station.
# Querying data for station: WSUGNE15
# No data found for this station.
# Querying data for station: WSUGNE20
# No data found for this station.
# Querying data for station: WSUGNE25
# No data found for this station.
# Querying data for station: WSUGNE30
# No data found for this station.
# Querying data for station: WSUGNE35
# No data found for this station.
# Querying data for station: WSUGNRP1
# No data found for this station.
# Querying data for station: WSUGNSD1
# No data found for this station.
# Querying data for station: 405212
# Querying data for station: WSWINCIF
# No data found for this station.
# Querying data for station: WSWINW00
# No data found for this station.
# Querying data for station: WSWINW02
# No data found for this station.
# Querying data for station: WSWINW04
# No data found for this station.
# Querying data for station: WSWINW06
# No data found for this station.
# Querying data for station: WSWIS204
# No data found for this station.
# Querying data for station: WSWIS202
# No data found for this station.
# Querying data for station: WSWIS200
# No data found for this station.
# Querying data for station: A4261027
# Querying data for station: A4260579
# Querying data for station: 340012
# Querying data for station: 340001
# Querying data for station: 410775
# Querying data for station: WTHOMTAC
# No data found for this station.
# Querying data for station: 223209
# Querying data for station: 223213
# Querying data for station: 223214
# No data found for this station.
# Querying data for station: WTARCRCK
# Querying data for station: WTARDIVW
# Querying data for station: WTARESPO
# Querying data for station: WTARRESO
# Querying data for station: WTARES10
# Querying data for station: WTARES00
# Querying data for station: WTARBOTT
# Querying data for station: WTARES20
# No data found for this station.
# Querying data for station: WTARESP0
# No data found for this station.
# Querying data for station: WTARESPB
# No data found for this station.
# Querying data for station: WTARRVTD
# No data found for this station.
# Querying data for station: WTAREAST
# Querying data for station: WTRWBBT1
# No data found for this station.
# Querying data for station: WTRPSMTK
# No data found for this station.
# Querying data for station: WTTPDISB
# No data found for this station.
# Querying data for station: WTTPRAWI
# Querying data for station: 410047
# Querying data for station: 2122713
# Querying data for station: 410187
# Querying data for station: 2122725
# Querying data for station: 42510080
# No data found for this station.
# Querying data for station: 225232
# Querying data for station: 225212
# Querying data for station: WTORTVR1
# No data found for this station.
# Querying data for station: WTORDJ11
# No data found for this station.
# Querying data for station: WTORSWIL
# No data found for this station.
# Querying data for station: WTORUSSW
# No data found for this station.
# Querying data for station: WTORDW02
# No data found for this station.
# Querying data for station: WTORDW03
# No data found for this station.
# Querying data for station: WTORDO21
# No data found for this station.
# Querying data for station: WTOMRSLB
# No data found for this station.
# Querying data for station: WTORUW01
# No data found for this station.
# Querying data for station: WTOMBBOT
# Querying data for station: WTOMAO00
# Querying data for station: WTOMAO05
# Querying data for station: WTOMAO06
# Querying data for station: WTOMAO10
# Querying data for station: WTOMAO15
# No data found for this station.
# Querying data for station: WTOMAO20
# Querying data for station: WTOMAO25
# No data found for this station.
# Querying data for station: WTOMAO30
# No data found for this station.
# Querying data for station: WTOMAO35
# No data found for this station.
# Querying data for station: WTOMAO40
# No data found for this station.
# Querying data for station: WTOMAO45
# No data found for this station.
# Querying data for station: WTOMAO50
# No data found for this station.
# Querying data for station: WTOMLBCK
# No data found for this station.
# Querying data for station: WTOM1100
# No data found for this station.
# Querying data for station: WTOMWBOT
# No data found for this station.
# Querying data for station: WTOM1090
# No data found for this station.
# Querying data for station: WTOM1080
# No data found for this station.
# Querying data for station: WTOM1075
# No data found for this station.
# Querying data for station: WTOM1070
# No data found for this station.
# Querying data for station: WTOM1060
# No data found for this station.
# Querying data for station: WTOM1055
# No data found for this station.
# Querying data for station: WTOM1050
# Querying data for station: WTOM1045
# No data found for this station.
# Querying data for station: WTOM1040
# No data found for this station.
# Querying data for station: WTOM1030
# Querying data for station: WTOM1020
# Querying data for station: WTOM1010
# No data found for this station.
# Querying data for station: WTOM1006
# No data found for this station.
# Querying data for station: WTOM1005
# No data found for this station.
# Querying data for station: WTOM1000
# Querying data for station: WTOM1025
# No data found for this station.
# Querying data for station: WTOM1015
# No data found for this station.
# Querying data for station: WTOM1035
# No data found for this station.
# Querying data for station: WTORAJ11
# No data found for this station.
# Querying data for station: WTORDSE1
# No data found for this station.
# Querying data for station: WTORDW01
# Querying data for station: 409109
# Querying data for station: 405730
# Querying data for station: 401014
# Querying data for station: WYYNIR01
# No data found for this station.
# Querying data for station: 409207
# Querying data for station: 401024
# Querying data for station: 401007
# Querying data for station: 410073
# Querying data for station: 409056
# Querying data for station: 409055
# No data found for this station.
# Querying data for station: WTYABSTI
# No data found for this station.
# Querying data for station: WTYABSTO
# No data found for this station.
# Querying data for station: WTYABST2
# No data found for this station.
# Querying data for station: 412186
# No data found for this station.
# Querying data for station: WTYBASOL
# No data found for this station.
# Querying data for station: 415608
# Querying data for station: 410779
# Querying data for station: WUYDNO5A
# No data found for this station.
# Querying data for station: WUYDNO5B
# No data found for this station.
# Querying data for station: WUYDNW10
# Querying data for station: WUYDNW80
# No data found for this station.
# Querying data for station: WUYDNW75
# No data found for this station.
# Querying data for station: WUYDNW70
# No data found for this station.
# Querying data for station: WUYDNW65
# No data found for this station.
# Querying data for station: WUYDNW60
# No data found for this station.
# Querying data for station: WUYDNW55
# No data found for this station.
# Querying data for station: WUYDNW50
# No data found for this station.
# Querying data for station: WUYDNW40
# Querying data for station: WUYDNW35
# No data found for this station.
# Querying data for station: WUYDNW30
# Querying data for station: WUYDNW25
# No data found for this station.
# Querying data for station: WUYDBOTT
# Querying data for station: WUYDNW00
# Querying data for station: WUYDNW05
# No data found for this station.
# Querying data for station: WUYDNW15
# No data found for this station.
# Querying data for station: WUYDNW20
# Querying data for station: WUYDNW08
# No data found for this station.
# Querying data for station: WUYDSWAY
# No data found for this station.
# Querying data for station: WUYDTOMI
# No data found for this station.
# Querying data for station: WUYDYRIL
# No data found for this station.
# Querying data for station: WUYDBGOT
# No data found for this station.
# Querying data for station: WUYDBGI2
# No data found for this station.
# Querying data for station: WUYDWAMD
# No data found for this station.
# Querying data for station: WUYDWAA1
# No data found for this station.
# Querying data for station: WUYDWALS
# No data found for this station.
# Querying data for station: WUYDNW45
# No data found for this station.
# Querying data for station: WUYDWAIL
# No data found for this station.
# Querying data for station: WUYBRAR5
# No data found for this station.
# Querying data for station: WUYCLR31
# Querying data for station: WUYCLR04
# No data found for this station.
# Querying data for station: WUYCOORI
# No data found for this station.
# Querying data for station: WUYDAMP4
# No data found for this station.
# Querying data for station: WUYSNOB1
# No data found for this station.
# Querying data for station: WUYWALR1
# Querying data for station: WUYDAHD1
# No data found for this station.
# Querying data for station: WUYDAHD2
# No data found for this station.
# Querying data for station: 409013
# Querying data for station: 409061
# Querying data for station: 409062
# Querying data for station: 409045
# Querying data for station: WWALCKAO
# No data found for this station.
# Querying data for station: WWALBCKW
# Querying data for station: WWALCKDO
# No data found for this station.
# Querying data for station: WWALCKDT
# No data found for this station.
# Querying data for station: WWSHIR01
# No data found for this station.
# Querying data for station: 238204
# Querying data for station: 238228
# Querying data for station: 233223
# Querying data for station: 412184
# No data found for this station.
# Querying data for station: 412185
# No data found for this station.
# Querying data for station: 405297
# Querying data for station: WWCKCALR
# No data found for this station.
# Querying data for station: WWCKHENR
# No data found for this station.
# Querying data for station: WWCKUSCK
# No data found for this station.
# Querying data for station: WWATSEMD
# No data found for this station.
# Querying data for station: WWATSCMD
# No data found for this station.
# Querying data for station: WWATDSMD
# No data found for this station.
# Querying data for station: WWATUR01
# No data found for this station.
# Querying data for station: WWATRR32
# Querying data for station: 401016
# Querying data for station: 425010B
# Querying data for station: WWOSRR03
# No data found for this station.
# Querying data for station: WWPINDBO
# No data found for this station.
# Querying data for station: WTHOMWLC
# No data found for this station.
# Querying data for station: WWILDR44
# No data found for this station.
# Querying data for station: 406235
# Querying data for station: 410166
# No data found for this station.
# Querying data for station: 415200
# Querying data for station: 415246
# Querying data for station: WWINCFOL
# Querying data for station: WWICSIR1
# Querying data for station: 234201
# Querying data for station: 234200
# Querying data for station: 409089
# No data found for this station.
# Querying data for station: 409076
# No data found for this station.
# Querying data for station: 233261
# No data found for this station.
# Querying data for station: 409084
# No data found for this station.
# Querying data for station: WYYTRCWC
# Querying data for station: WYYNRE01
# No data found for this station.
# Querying data for station: WYRESINT
# Querying data for station: WYYNXI02
# No data found for this station.
# Querying data for station: WYYNXI04
# No data found for this station.
# Querying data for station: WYYRES04
# No data found for this station.
# Querying data for station: WYYNXI06
# No data found for this station.
# Querying data for station: WYYNXI08
# No data found for this station.
# Querying data for station: WYYRCWCS
# Querying data for station: WYYRED02
# No data found for this station.
# Querying data for station: WYRESBOT
# Querying data for station: WYYRES01
# No data found for this station.
# Querying data for station: WYYRES02
# No data found for this station.
# Querying data for station: WYYNNT11
# No data found for this station.
# Querying data for station: WYYNXBOT
# No data found for this station.
# Querying data for station: WYYNXI00
# No data found for this station.
# Querying data for station: WYYRES00
# Querying data for station: WYYTOW00
# Querying data for station: 410169
# Querying data for station: 229143
# No data found for this station.
# Querying data for station: 229200
# No data found for this station.
# Querying data for station: 229653
# No data found for this station.
# Querying data for station: WYARBCHR
# No data found for this station.
# Querying data for station: WYARYENG
# Querying data for station: WYASAS01
# No data found for this station.
# Querying data for station: WYASIR01
# No data found for this station.
# Querying data for station: 410176
# Querying data for station: 410090
# Querying data for station: WYSCIR01
# Querying data for station: WYAVIR01
# Querying data for station: WWRBLYRB
# Querying data for station: WCWCTRIL
# Querying data for station: A2391075
# Station                       2122518 2122711 2122713 2122725 215208 215209  \
# Time
# 2010-01-01T00:00:00.000+10:00     NaN     NaN     NaN     NaN    NaN    NaN
# 2010-01-01T00:30:00.000+10:00     NaN     NaN     NaN     NaN    NaN    NaN
# 2010-01-02T00:00:00.000+10:00     NaN     NaN     NaN     NaN    NaN    NaN
# 2010-01-02T00:30:00.000+10:00     NaN     NaN     NaN     NaN    NaN    NaN
# 2010-01-03T00:00:00.000+10:00     NaN     NaN     NaN     NaN    NaN    NaN
# ...                               ...     ...     ...     ...    ...    ...
# 2023-12-30T00:00:00.000+10:00   559.1  7566.7     0.0     NaN    NaN    NaN
# 2023-12-30T00:30:00.000+10:00     NaN     NaN     NaN     NaN    NaN    NaN
# 2023-12-31T00:00:00.000+10:00   558.5  7523.5     0.0     NaN    NaN    NaN
# 2023-12-31T00:30:00.000+10:00     NaN     NaN     NaN     NaN    NaN    NaN
# 2024-01-01T00:00:00.000+10:00   557.8  7310.9     0.0     NaN    NaN    NaN
#
# Station                       215237 215237B 217006 219003  ... A4261022  \
# Time                                                        ...
# 2010-01-01T00:00:00.000+10:00    NaN     NaN  336.7   70.4  ...      NaN
# 2010-01-01T00:30:00.000+10:00    NaN     NaN    NaN    NaN  ...      113
# 2010-01-02T00:00:00.000+10:00    NaN     NaN  331.6   69.2  ...      NaN
# 2010-01-02T00:30:00.000+10:00    NaN     NaN    NaN    NaN  ...      107
# 2010-01-03T00:00:00.000+10:00    NaN     NaN  325.0   73.8  ...      NaN
# ...                              ...     ...    ...    ...  ...      ...
# 2023-12-30T00:00:00.000+10:00    NaN     0.0    NaN    NaN  ...      NaN
# 2023-12-30T00:30:00.000+10:00    NaN     NaN    NaN    NaN  ...      274
# 2023-12-31T00:00:00.000+10:00    NaN     0.0    NaN    NaN  ...      NaN
# 2023-12-31T00:30:00.000+10:00    NaN     NaN    NaN    NaN  ...      275
# 2024-01-01T00:00:00.000+10:00    NaN     0.0    NaN    NaN  ...      NaN
#
# Station                       A4261027 A4261051 A4261059 A4261091 A4261093  \
# Time
# 2010-01-01T00:00:00.000+10:00      NaN      NaN      NaN      NaN      NaN
# 2010-01-01T00:30:00.000+10:00      284      193      194      147    190.9
# 2010-01-02T00:00:00.000+10:00      NaN      NaN      NaN      NaN      NaN
# 2010-01-02T00:30:00.000+10:00      401      212      205      149    189.1
# 2010-01-03T00:00:00.000+10:00      NaN      NaN      NaN      NaN      NaN
# ...                                ...      ...      ...      ...      ...
# 2023-12-30T00:00:00.000+10:00      NaN      NaN      NaN      NaN      NaN
# 2023-12-30T00:30:00.000+10:00      586      NaN      299      NaN    273.2
# 2023-12-31T00:00:00.000+10:00      NaN      NaN      NaN      NaN      NaN
# 2023-12-31T00:30:00.000+10:00      568      NaN      300      NaN    274.4
# 2024-01-01T00:00:00.000+10:00      NaN      NaN      NaN      NaN      NaN
#
# Station                       A4261107 A4261224 A4261791 GW088184.1.1
# Time
# 2010-01-01T00:00:00.000+10:00      NaN      NaN      NaN          NaN
# 2010-01-01T00:30:00.000+10:00      NaN      147      NaN          NaN
# 2010-01-02T00:00:00.000+10:00      NaN      NaN      NaN          NaN
# 2010-01-02T00:30:00.000+10:00      NaN      149      NaN          NaN
# 2010-01-03T00:00:00.000+10:00      NaN      NaN      NaN          NaN
# ...                                ...      ...      ...          ...
# 2023-12-30T00:00:00.000+10:00      NaN      NaN      NaN          NaN
# 2023-12-30T00:30:00.000+10:00      266      414    279.7          NaN
# 2023-12-31T00:00:00.000+10:00      NaN      NaN      NaN          NaN
# 2023-12-31T00:30:00.000+10:00      231      406    287.5          NaN
# 2024-01-01T00:00:00.000+10:00      NaN      NaN      NaN          NaN
#
# [10227 rows x 311 columns]

# %%
pivot_df.to_csv('DailyEC.csv', index=True)
