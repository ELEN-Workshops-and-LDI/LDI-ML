# %%
# Set Variables
SW_LAT = -38.88917
SW_LON = 140.84444
NE_LAT = -33.70833
NE_LON = 150.0
TIMESCALE = "Monthly"


PARAMETER_NAME = f"Pat2_C_B_1_{TIMESCALE}Tot24"
PROPERTY_NAME = "Rainfall"
TIME_PERIOD = "2010/2024"
OUTPUT_DOC = f"{TIMESCALE}MeanRainfall"

# %%
import requests
from xml.etree.ElementTree import Element, SubElement, tostring

# Define the namespace map to use in the XML
ns = {
    'sos': "http://www.opengis.net/sos/2.0",
    'fes': "http://www.opengis.net/fes/2.0",
    'gml': "http://www.opengis.net/gml/3.2",
    'xsi': "http://www.w3.org/2001/XMLSchema-instance",
    'sams': "http://www.opengis.net/samplingSpatial/2.0"
}

# Define the endpoint URL for the SOS service
url = "http://www.bom.gov.au/waterdata/services"

# Create XML elements for the request
envelope = Element('sos:GetFeatureOfInterest', {
    'service': 'SOS', 'version': '2.0', 'xmlns:sos': ns['sos'], 'xmlns:fes': ns['fes'], 'xmlns:gml': ns['gml'], 'xmlns:xsi': ns['xsi'], 'xmlns:sams': ns['sams']
})

spatial_filter = SubElement(envelope, 'sos:spatialFilter')
bbox = SubElement(spatial_filter, 'fes:BBOX')
value_ref = SubElement(bbox, 'fes:ValueReference')
value_ref.text = 'om:featureOfInterest/*/sams:shape'

envelope_ = SubElement(bbox, 'gml:Envelope', {
    'srsName': 'urn:ogc:def:crs:EPSG::4326'
})
lower_corner = SubElement(envelope_, 'gml:lowerCorner')
upper_corner = SubElement(envelope_, 'gml:upperCorner')

# Insert the actual coordinates for the Murray River bounding box
lower_corner.text = f"{SW_LAT} {SW_LON}"  # Southernmost, westernmost
upper_corner.text = f"{NE_LAT} {NE_LON}"  # Northernmost, easternmost

# Add observed property element
observed_property = SubElement(envelope, 'sos:observedProperty')
observed_property.text = f"http://bom.gov.au/waterdata/services/parameters/{PROPERTY_NAME}"  # Example observed property


# Convert the ElementTree to a string
request_xml = tostring(envelope, 'utf-8')

# Define headers for the POST request
headers = {
    'Content-Type': 'application/xml'
}

# Send the POST request
FeatureOfInterestResponse = requests.post(url, data=request_xml, headers=headers)

# Print the response from the server

# %%
import requests
import xml.etree.ElementTree as ET
# Sample XML response from GetFeatureOfInterest
xml_response = FeatureOfInterestResponse.text

# Parse the XML string
root = ET.fromstring(xml_response)

# Extract station IDs
station_ids = [elem.text.split('/')[-1] for elem in root.findall('.//gml:identifier', namespaces={'gml': 'http://www.opengis.net/gml/3.2'})]

print(station_ids) 

#get stations within region
# Out:
# ['403213', '407289', '41200209', '412028', '225812A', '225100A', '405209', '573016', '227211', '233250', '502254A', '587047', '41000271', '408216', '229628A', '229620A', '586202', '408206', '408200', '408800', '225224', '225201', '415220', '230806A', '406262', '406216', '00300', 'ST965', '229859A', 'ST910', 'SP073', '570806', '072082', 'BAGOG1', 'BAGOG3', 'BAGOG4', '406751', '233218', '233224', '233200', '227231', '227219', '227231A', '227219A', '228268A', '410137', '586195', '219900', '219032', '412135', '225817A', '585069', '41010904', '586199', '407211', '407288', '407220', '401216', '585064', '407609', '229670', '228366A', '410102', '587037', '502241A', '403226', '230211A', '412029', '404204', '232221', '401015', '409058', '409057', '230219', '586095', '230808A', '410077', '41000270', '229857A', '222202', '219027', '219007', '219025', '404224', '404214', '404206', '404243', '41000279', '600577', '219030', '234212', '236212', '41000269', '229249A', '222206', '403233', '403253', '403220', '587014', '407287', '407290', '408801', '228369A', '215014', '228255A', '228207A', '228213A', '228395A', '228212A', '41000280', '410131', '570967', 'ST801', '409113', 'SB511', '570958', 'A2391089', 'ST390A', '570955', 'RE670', '570951', '407284', '229810A', '406202', '406213', '406218', '221209', '228228A', '228382A', '231821A', '228820A', '405246', '405308', '586194', '586115', '228826A', '228603A', '219033', '407726', '407727', '406220', '406250', '406221', '415237', '401230', '072169', '228821A', '586375', '502296A', '401208', '401229', '235203', '00014', '00015', 'sp-o10138', '236805', '570804', 'A4261167', '570802', '00009', '570947', 'SP038', '570946', '410730', '410704', '218005', '228373A', '228356B', '228368A', '228357A', '228823A', '229612A', '229613A', '229403A', '224213', '409070', '409053', '409069', '406755', '406704', '234209', '230100A', '230107A', '405214', '222008', '231820A', '232235', '586206', '086357', '219012', '229619B', '229290A', '586100', '586037', '586010', '41000275', '231710A', '238220', '232800A', 'sp-o10298', '570803', '412152', '228233A', '585016', '409014', '409023', '228371A', '502213A', '229638A', '229660A', '229858A', '586033', '586182', '228235A', '228203C', 'EW0902', '586026', '570903', '587041', '406266', '587024', '405245', '228822A', '228819A', '232223', '225218', '570817', '570801', '405293', '229624A', '229625A', '229231B', '229636A', '221210', '221001', '401217', '225709A', '229846A', '586197', '502219A', '225230', '41010922', '410057', '41000261', '405714', '405219', '405200', '405202', '405253', '405259', '086305', '586028', 'GRNG02', '403246', '228365A', '221052', 'CS033', '00214', '221056', '570908', '570807', '570991', '570818', '570823', 'sp-o10438', '221054', '570915', '570970', '570990', '570992', '00052', '00008', '405294', '228231A', '586036', '403214', '41010928', '502251A', '228262A', '410534', '404207', '405274', '236219', '231822A', '412902', '401027', '403224', 'A2391087', '570916', '570904', '502269A', '00018', '230202', '230233', '230104', '230103A', '230104A', '225818A', '410112', '502240A', '401013', '410025', '073019', '00072', '00004', '073025', '230200D', '235211', '407770', '586175', '402205', '402222', '402203A', '402203', '410114', '403227', '403234', '405231', '586205', '228825A', '231222A', '231104A', '231107A', '231105B', '231106A', '232230', '410156', '570821', 'A2391088', '95907', 'RE690', '410997', '412065', '412002', '587023', '415610', '415227', '512223A', '232219', '232220', '232222', '587026', '415275', '228209B', '502248A', '226205', '226222', '231819A', '233215', '233213', '233248', '231211', '231211A', '407326', '502266A', '414215', '414213', '232200', '585024', '409399', '232200C', '232242A', '234616', '234701', '407712', '407240', '407217', '231245A', '502270A', '229244A', '238710', 'sp-o10606', '570924', 'LAKE_BELLFIELD', 'sp-o10109', 'sp-o10350', 'LAKE_FYANS', '570996', 'LAKE_LONSDALE', 'sp-o10806', 'sp-o10930', 'A4260904', 'sp-o11590', 'SP036', '407221', ...

# %%
import requests
from xml.etree import ElementTree as ET
import pandas as pd

# Define the SOS2 endpoint URL
url = "http://www.bom.gov.au/waterdata/services"

data = []  # List to store data for DataFrame


# Define the parameters for the GetObservation request
params = {
    'service': 'SOS',
    'version': '2.0.0',
    'request': 'GetObservation',
    'procedure': f"http://bom.gov.au/waterdata/services/tstypes/{PARAMETER_NAME}",
    'observedProperty': f"http://bom.gov.au/waterdata/services/parameters/{PROPERTY_NAME}",
    'temporalFilter': f"om:phenomenonTime,{TIME_PERIOD}"
}

# Assuming station_ids is defined earlier in the script
for station_id in station_ids:
    print(f"Querying data for station: {station_id}")
    
    # Add the station ID to the parameters
    params['featureOfInterest'] = f"http://bom.gov.au/waterdata/services/stations/{station_id}"
    
    # Make the GetObservation request to the SOS2 endpoint
    response = requests.get(url, params=params, timeout=100)  # Added timeout
    
    if response.status_code == 200:
        # Parse the XML response
        root = ET.fromstring(response.content)
        
        # Find all the MeasurementTVP elements which contain the time-value pairs
        tvp_elements = root.findall('.//{http://www.opengis.net/waterml/2.0}MeasurementTVP')
        
        if not tvp_elements:
            print("No data found for this station.")
        else:
            # Print out the time and value for each MeasurementTVP
            for tvp in tvp_elements:
                time = tvp.find('{http://www.opengis.net/waterml/2.0}time').text
                value = tvp.find('{http://www.opengis.net/waterml/2.0}value').text
                #print(f"  {time}: {value}")
                data.append({'Station': station_id, 'Time': time, 'Value': value})
    else:
        print(f"Failed to retrieve data for station {station_id}. HTTP status code: {response.status_code}")
        print("Response Headers:", response.headers)
        print("Response Body:", response.text)


df = pd.DataFrame(data)
# Out:
# Querying data for station: 403213
# Querying data for station: 407289
# Querying data for station: 41200209
# Querying data for station: 412028
# Querying data for station: 225812A
# Querying data for station: 225100A
# No data found for this station.
# Querying data for station: 405209
# Querying data for station: 573016
# Querying data for station: 227211
# No data found for this station.
# Querying data for station: 233250
# Querying data for station: 502254A
# No data found for this station.
# Querying data for station: 587047
# Querying data for station: 41000271
# Querying data for station: 408216
# Querying data for station: 229628A
# Querying data for station: 229620A
# Querying data for station: 586202
# Querying data for station: 408206
# Querying data for station: 408200
# Querying data for station: 408800
# Querying data for station: 225224
# Querying data for station: 225201
# Querying data for station: 415220
# Querying data for station: 230806A
# Querying data for station: 406262
# Querying data for station: 406216
# Querying data for station: 00300
# Querying data for station: ST965
# Querying data for station: 229859A
# Querying data for station: ST910
# Querying data for station: SP073
# Querying data for station: 570806
# Querying data for station: 072082
# Querying data for station: BAGOG1
# Querying data for station: BAGOG3
# No data found for this station.
# Querying data for station: BAGOG4
# No data found for this station.
# Querying data for station: 406751
# Querying data for station: 233218
# Querying data for station: 233224
# Querying data for station: 233200
# Querying data for station: 227231
# Querying data for station: 227219
# Querying data for station: 227231A
# Querying data for station: 227219A
# Querying data for station: 228268A
# Querying data for station: 410137
# Querying data for station: 586195
# Querying data for station: 219900
# Querying data for station: 219032
# Querying data for station: 412135
# No data found for this station.
# Querying data for station: 225817A
# Querying data for station: 585069
# No data found for this station.
# Querying data for station: 41010904
# Querying data for station: 586199
# Querying data for station: 407211
# Querying data for station: 407288
# Querying data for station: 407220
# Querying data for station: 401216
# Querying data for station: 585064
# No data found for this station.
# Querying data for station: 407609
# Querying data for station: 229670
# No data found for this station.
# Querying data for station: 228366A
# Querying data for station: 410102
# Querying data for station: 587037
# Querying data for station: 502241A
# No data found for this station.
# Querying data for station: 403226
# Querying data for station: 230211A
# Querying data for station: 412029
# Querying data for station: 404204
# Querying data for station: 232221
# Querying data for station: 401015
# Querying data for station: 409058
# No data found for this station.
# Querying data for station: 409057
# No data found for this station.
# Querying data for station: 230219
# No data found for this station.
# Querying data for station: 586095
# Querying data for station: 230808A
# Querying data for station: 410077
# No data found for this station.
# Querying data for station: 41000270
# Querying data for station: 229857A
# Querying data for station: 222202
# No data found for this station.
# Querying data for station: 219027
# Querying data for station: 219007
# No data found for this station.
# Querying data for station: 219025
# Querying data for station: 404224
# Querying data for station: 404214
# Querying data for station: 404206
# Querying data for station: 404243
# Querying data for station: 41000279
# Querying data for station: 600577
# Querying data for station: 219030
# No data found for this station.
# Querying data for station: 234212
# Querying data for station: 236212
# Querying data for station: 41000269
# Querying data for station: 229249A
# Querying data for station: 222206
# Querying data for station: 403233
# Querying data for station: 403253
# Querying data for station: 403220
# Querying data for station: 587014
# Querying data for station: 407287
# Querying data for station: 407290
# Querying data for station: 408801
# Querying data for station: 228369A
# Querying data for station: 215014
# Querying data for station: 228255A
# Querying data for station: 228207A
# Querying data for station: 228213A
# Querying data for station: 228395A
# Querying data for station: 228212A
# Querying data for station: 41000280
# Querying data for station: 410131
# Querying data for station: 570967
# Querying data for station: ST801
# Querying data for station: 409113
# Querying data for station: SB511
# Querying data for station: 570958
# Querying data for station: A2391089
# Querying data for station: ST390A
# Querying data for station: 570955
# Querying data for station: RE670
# Querying data for station: 570951
# Querying data for station: 407284
# Querying data for station: 229810A
# Querying data for station: 406202
# Querying data for station: 406213
# Querying data for station: 406218
# Querying data for station: 221209
# Querying data for station: 228228A
# Querying data for station: 228382A
# Querying data for station: 231821A
# Querying data for station: 228820A
# Querying data for station: 405246
# Querying data for station: 405308
# Querying data for station: 586194
# Querying data for station: 586115
# Querying data for station: 228826A
# Querying data for station: 228603A
# Querying data for station: 219033
# Querying data for station: 407726
# No data found for this station.
# Querying data for station: 407727
# No data found for this station.
# Querying data for station: 406220
# Querying data for station: 406250
# Querying data for station: 406221
# No data found for this station.
# Querying data for station: 415237
# Querying data for station: 401230
# Querying data for station: 072169
# Querying data for station: 228821A
# Querying data for station: 586375
# Querying data for station: 502296A
# No data found for this station.
# Querying data for station: 401208
# Querying data for station: 401229
# Querying data for station: 235203
# Querying data for station: 00014
# Querying data for station: 00015
# Querying data for station: sp-o10138
# Querying data for station: 236805
# Querying data for station: 570804
# Querying data for station: A4261167
# Querying data for station: 570802
# Querying data for station: 00009
# Querying data for station: 570947
# Querying data for station: SP038
# Querying data for station: 570946
# Querying data for station: 410730
# Querying data for station: 410704
# Querying data for station: 218005
# No data found for this station.
# Querying data for station: 228373A
# Querying data for station: 228356B
# Querying data for station: 228368A
# Querying data for station: 228357A
# Querying data for station: 228823A
# Querying data for station: 229612A
# Querying data for station: 229613A
# Querying data for station: 229403A
# Querying data for station: 224213
# Querying data for station: 409070
# No data found for this station.
# Querying data for station: 409053
# No data found for this station.
# Querying data for station: 409069
# No data found for this station.
# Querying data for station: 406755
# No data found for this station.
# Querying data for station: 406704
# Querying data for station: 234209
# Querying data for station: 230100A
# Querying data for station: 230107A
# Querying data for station: 405214
# Querying data for station: 222008
# Querying data for station: 231820A
# Querying data for station: 232235
# Querying data for station: 586206
# Querying data for station: 086357
# Querying data for station: 219012
# No data found for this station.
# Querying data for station: 229619B
# Querying data for station: 229290A
# Querying data for station: 586100
# Querying data for station: 586037
# Querying data for station: 586010
# Querying data for station: 41000275
# Querying data for station: 231710A
# Querying data for station: 238220
# Querying data for station: 232800A
# Querying data for station: sp-o10298
# Querying data for station: 570803
# Querying data for station: 412152
# Querying data for station: 228233A
# Querying data for station: 585016
# No data found for this station.
# Querying data for station: 409014
# Querying data for station: 409023
# Querying data for station: 228371A
# Querying data for station: 502213A
# No data found for this station.
# Querying data for station: 229638A
# Querying data for station: 229660A
# Querying data for station: 229858A
# Querying data for station: 586033
# Querying data for station: 586182
# Querying data for station: 228235A
# Querying data for station: 228203C
# Querying data for station: EW0902
# Querying data for station: 586026
# No data found for this station.
# Querying data for station: 570903
# Querying data for station: 587041
# Querying data for station: 406266
# Querying data for station: 587024
# Querying data for station: 405245
# No data found for this station.
# Querying data for station: 228822A
# Querying data for station: 228819A
# Querying data for station: 232223
# No data found for this station.
# Querying data for station: 225218
# Querying data for station: 570817
# Querying data for station: 570801
# Querying data for station: 405293
# Querying data for station: 229624A
# Querying data for station: 229625A
# Querying data for station: 229231B
# Querying data for station: 229636A
# Querying data for station: 221210
# Querying data for station: 221001
# Querying data for station: 401217
# Querying data for station: 225709A
# Querying data for station: 229846A
# Querying data for station: 586197
# Querying data for station: 502219A
# No data found for this station.
# Querying data for station: 225230
# Querying data for station: 41010922
# Querying data for station: 410057
# Querying data for station: 41000261
# Querying data for station: 405714
# Querying data for station: 405219
# Querying data for station: 405200
# Querying data for station: 405202
# No data found for this station.
# Querying data for station: 405253
# Querying data for station: 405259
# Querying data for station: 086305
# Querying data for station: 586028
# Querying data for station: GRNG02
# Querying data for station: 403246
# No data found for this station.
# Querying data for station: 228365A
# Querying data for station: 221052
# Querying data for station: CS033
# Querying data for station: 00214
# Querying data for station: 221056
# Querying data for station: 570908
# Querying data for station: 570807
# Querying data for station: 570991
# Querying data for station: 570818
# Querying data for station: 570823
# Querying data for station: sp-o10438
# Querying data for station: 221054
# Querying data for station: 570915
# Querying data for station: 570970
# Querying data for station: 570990
# Querying data for station: 570992
# Querying data for station: 00052
# Querying data for station: 00008
# Querying data for station: 405294
# Querying data for station: 228231A
# Querying data for station: 586036
# Querying data for station: 403214
# Querying data for station: 41010928
# Querying data for station: 502251A
# No data found for this station.
# Querying data for station: 228262A
# Querying data for station: 410534
# Querying data for station: 404207
# Querying data for station: 405274
# Querying data for station: 236219
# Querying data for station: 231822A
# Querying data for station: 412902
# Querying data for station: 401027
# Querying data for station: 403224
# Querying data for station: A2391087
# Querying data for station: 570916
# Querying data for station: 570904
# Querying data for station: 502269A
# No data found for this station.
# Querying data for station: 00018
# Querying data for station: 230202
# Querying data for station: 230233
# Querying data for station: 230104
# Querying data for station: 230103A
# Querying data for station: 230104A
# Querying data for station: 225818A
# Querying data for station: 410112
# Querying data for station: 502240A
# No data found for this station.
# Querying data for station: 401013
# Querying data for station: 410025
# Querying data for station: 073019
# Querying data for station: 00072
# Querying data for station: 00004
# Querying data for station: 073025
# Querying data for station: 230200D
# Querying data for station: 235211
# Querying data for station: 407770
# No data found for this station.
# Querying data for station: 586175
# Querying data for station: 402205
# Querying data for station: 402222
# Querying data for station: 402203A
# Querying data for station: 402203
# Querying data for station: 410114
# Querying data for station: 403227
# Querying data for station: 403234
# Querying data for station: 405231
# Querying data for station: 586205
# Querying data for station: 228825A
# Querying data for station: 231222A
# Querying data for station: 231104A
# Querying data for station: 231107A
# Querying data for station: 231105B
# Querying data for station: 231106A
# Querying data for station: 232230
# Querying data for station: 410156
# Querying data for station: 570821
# Querying data for station: A2391088
# Querying data for station: 95907
# Querying data for station: RE690
# Querying data for station: 410997
# Querying data for station: 412065
# Querying data for station: 412002
# Querying data for station: 587023
# Querying data for station: 415610
# Querying data for station: 415227
# Querying data for station: 512223A
# No data found for this station.
# Querying data for station: 232219
# Querying data for station: 232220
# Querying data for station: 232222
# Querying data for station: 587026
# Querying data for station: 415275
# Querying data for station: 228209B
# Querying data for station: 502248A
# No data found for this station.
# Querying data for station: 226205
# Querying data for station: 226222
# No data found for this station.
# Querying data for station: 231819A
# Querying data for station: 233215
# Querying data for station: 233213
# Querying data for station: 233248
# Querying data for station: 231211
# Querying data for station: 231211A
# Querying data for station: 407326
# Querying data for station: 502266A
# No data found for this station.
# Querying data for station: 414215
# No data found for this station.
# Querying data for station: 414213
# No data found for this station.
# Querying data for station: 232200
# Querying data for station: 585024
# No data found for this station.
# Querying data for station: 409399
# Querying data for station: 232200C
# Querying data for station: 232242A
# Querying data for station: 234616
# Querying data for station: 234701
# Querying data for station: 407712
# Querying data for station: 407240
# Querying data for station: 407217
# Querying data for station: 231245A
# Querying data for station: 502270A
# No data found for this station.
# Querying data for station: 229244A
# Querying data for station: 238710
# No data found for this station.
# Querying data for station: sp-o10606
# Querying data for station: 570924
# No data found for this station.
# Querying data for station: LAKE_BELLFIELD
# Querying data for station: sp-o10109
# Querying data for station: sp-o10350
# Querying data for station: LAKE_FYANS
# Querying data for station: 570996
# Querying data for station: LAKE_LONSDALE
# Querying data for station: sp-o10806
# Querying data for station: sp-o10930
# Querying data for station: A4260904
# Querying data for station: sp-o11590
# Querying data for station: SP036
# Querying data for station: 407221
# Querying data for station: LAURISTON
# Querying data for station: SP025
# Querying data for station: 410776
# Querying data for station: 570922
# Querying data for station: 570977
# Querying data for station: ST940
# Querying data for station: 570953
# Querying data for station: 570985
# Querying data for station: 409711
# Querying data for station: 409712
# Querying data for station: 41000272
# Querying data for station: 410023
# Querying data for station: 410082
# Querying data for station: 410136
# Querying data for station: 401019
# No data found for this station.
# Querying data for station: 225219
# Querying data for station: 225225
# Querying data for station: 225209
# Querying data for station: 225221
# Querying data for station: 222017
# Querying data for station: 410127
# No data found for this station.
# Querying data for station: 405248
# Querying data for station: 401029
# Querying data for station: 401008
# Querying data for station: 401026
# Querying data for station: 401009
# Querying data for station: 230200
# Querying data for station: 230105A
# Querying data for station: 230106A
# Querying data for station: 086070
# Querying data for station: 502300A
# No data found for this station.
# Querying data for station: 502293A
# No data found for this station.
# Querying data for station: 41010941
# Querying data for station: 410535
# Querying data for station: 586187
# Querying data for station: 229402A
# Querying data for station: 229645A
# Querying data for station: 229257A
# Querying data for station: 229627A
# Querying data for station: 229149A
# Querying data for station: 229603A
# Querying data for station: 227239
# Querying data for station: 233251
# No data found for this station.
# Querying data for station: 228362A
# Querying data for station: 406264
# Querying data for station: 502255A
# No data found for this station.
# Querying data for station: 41000282
# Querying data for station: 086074
# Querying data for station: 586006
# Querying data for station: 224200
# No data found for this station.
# Querying data for station: 224217
# Querying data for station: 224218A
# No data found for this station.
# Querying data for station: 224203
# Querying data for station: 401203
# Querying data for station: 401204
# Querying data for station: 226209
# Querying data for station: 405238
# Querying data for station: 228229B
# Querying data for station: 215210
# Querying data for station: 215007
# Querying data for station: 502244A
# No data found for this station.
# Querying data for station: 229643A
# Querying data for station: 229665A
# Querying data for station: 238702
# Querying data for station: 232210
# Querying data for station: 232204
# Querying data for station: 401215
# Querying data for station: 226407
# Querying data for station: 406756
# Querying data for station: 415605
# Querying data for station: 236213
# Querying data for station: 406224
# Querying data for station: 237208
# Querying data for station: 587066
# Querying data for station: 587000
# Querying data for station: 586090
# Querying data for station: 512220A
# No data found for this station.
# Querying data for station: 229814A
# Querying data for station: 502261A
# No data found for this station.
# Querying data for station: 229849A
# Querying data for station: 587036
# Querying data for station: 229805A
# Querying data for station: 229820A
# Querying data for station: 587126
# Querying data for station: 502262A
# No data found for this station.
# Querying data for station: 225813A
# Querying data for station: 586097
# Querying data for station: 229811A
# Querying data for station: 502275A
# No data found for this station.
# Querying data for station: 585065
# No data found for this station.
# Querying data for station: 585063
# No data found for this station.
# Querying data for station: 415252
# Querying data for station: 404714
# Querying data for station: 407300
# Querying data for station: 406263
# Querying data for station: 573015
# Querying data for station: 401012
# Querying data for station: 401012B
# Querying data for station: 401201
# Querying data for station: 409216
# Querying data for station: 409216A
# Querying data for station: 502216A
# No data found for this station.
# Querying data for station: 41000207
# Querying data for station: 225811A
# Querying data for station: MALMSBURY
# Querying data for station: 570993
# Querying data for station: 570999
# Querying data for station: A2391091
# Querying data for station: EW1101
# Querying data for station: EW1102
# Querying data for station: 570954
# Querying data for station: 570925
# Querying data for station: SB049
# Querying data for station: MOORA
# Querying data for station: ME820
# Querying data for station: ME781
# Querying data for station: MT_COLE
# Querying data for station: ME949
# Querying data for station: 41001702
# Querying data for station: 502224A
# No data found for this station.
# Querying data for station: 234215
# Querying data for station: 226218
# Querying data for station: 410180
# No data found for this station.
# Querying data for station: 228804A
# Querying data for station: 502298A
# No data found for this station.
# Querying data for station: 407604
# Querying data for station: 238242
# No data found for this station.
# Querying data for station: 238709
# No data found for this station.
# Querying data for station: 410060
# Querying data for station: 586023
# Querying data for station: 586919
# Querying data for station: A2391260
# Querying data for station: A2391090
# Querying data for station: sp-o10926
# Querying data for station: FR110
# Querying data for station: 41001701
# Querying data for station: 229834A
# Querying data for station: 586185
# Querying data for station: 570351
# Querying data for station: 421201
# Querying data for station: 421189
# Querying data for station: 229672A
# Querying data for station: 229690A
# Querying data for station: 585070
# No data found for this station.
# Querying data for station: 229111A
# Querying data for station: 403205
# Querying data for station: 403244
# No data found for this station.
# Querying data for station: 403230
# Querying data for station: 403250
# Querying data for station: SP351
# Querying data for station: 570928
# Querying data for station: 570980
# Querying data for station: 570966
# Querying data for station: 229851A
# Querying data for station: 235264
# Querying data for station: 586201
# Querying data for station: 220003
# Querying data for station: 225816A
# Querying data for station: 231234
# Querying data for station: 231251A
# Querying data for station: 231234A
# Querying data for station: 572031
# Querying data for station: 229821A
# Querying data for station: 405290
# Querying data for station: 229216
# No data found for this station.
# Querying data for station: 229615A
# Querying data for station: 229614A
# Querying data for station: 229616A
# Querying data for station: 229400A
# Querying data for station: 229850A
# Querying data for station: 586021
# Querying data for station: 229804A
# Querying data for station: 586196
# Querying data for station: 502234A
# No data found for this station.
# Querying data for station: 229670A
# Querying data for station: 405226
# Querying data for station: 086096
# Querying data for station: 586011
# Querying data for station: 502211A
# No data found for this station.
# Querying data for station: 231223A
# Querying data for station: 570971
# Querying data for station: RE961
# Querying data for station: 221053
# Querying data for station: 570825
# Querying data for station: 221051
# Querying data for station: ST514A
# Querying data for station: 570816
# Querying data for station: 570983
# Querying data for station: 232802A
# Querying data for station: 570965
# Querying data for station: 225819
# No data found for this station.
# Querying data for station: 232806
# Querying data for station: 226818
# Querying data for station: 233814
# Querying data for station: 403803
# Querying data for station: 229803
# No data found for this station.
# Querying data for station: 225823
# Querying data for station: 233813
# Querying data for station: 229802
# No data found for this station.
# Querying data for station: 233815
# Querying data for station: 234801
# Querying data for station: 229800
# No data found for this station.
# Querying data for station: 229808
# No data found for this station.
# Querying data for station: 226817
# No data found for this station.
# Querying data for station: 405837
# Querying data for station: 233803
# Querying data for station: 226816
# No data found for this station.
# Querying data for station: 233802
# Querying data for station: 226814
# Querying data for station: 401825
# Querying data for station: 226804
# No data found for this station.
# Querying data for station: 229801
# No data found for this station.
# Querying data for station: 229804
# No data found for this station.
# Querying data for station: 405834
# No data found for this station.
# Querying data for station: 403805
# Querying data for station: 403804
# Querying data for station: 229819A
# Querying data for station: 226819
# Querying data for station: 226805
# No data found for this station.
# Querying data for station: 232800
# Querying data for station: 226815
# Querying data for station: 405836
# No data found for this station.
# Querying data for station: 407805
# Querying data for station: 404810
# Querying data for station: 404809
# Querying data for station: 235805
# Querying data for station: 235801
# Querying data for station: 235806
# Querying data for station: 225226A
# Querying data for station: 225227A
# No data found for this station.
# Querying data for station: 406802
# Querying data for station: 408218
# Querying data for station: 223804
# Querying data for station: 236809
# Querying data for station: 224220
# No data found for this station.
# Querying data for station: 221803
# Querying data for station: 401822
# Querying data for station: 221801
# Querying data for station: 221802
# Querying data for station: 402889
# No data found for this station.
# Querying data for station: 237801
# Querying data for station: 226829
# Querying data for station: 402888
# No data found for this station.
# Querying data for station: 402821
# No data found for this station.
# Querying data for station: 225809
# Querying data for station: 223800
# No data found for this station.
# Querying data for station: 225802
# Querying data for station: 225801
# Querying data for station: 225810
# Querying data for station: 402899
# No data found for this station.
# Querying data for station: 221800
# No data found for this station.
# Querying data for station: 226820
# Querying data for station: 221804
# Querying data for station: 236808
# Querying data for station: 225825
# Querying data for station: 226828
# Querying data for station: 226825
# Querying data for station: 225826
# Querying data for station: 225824
# Querying data for station: 226827
# Querying data for station: 226826
# Querying data for station: 232805
# Querying data for station: 401800
# Querying data for station: 226801
# No data found for this station.
# Querying data for station: 226802
# No data found for this station.
# Querying data for station: 231803
# No data found for this station.
# Querying data for station: 231801
# No data found for this station.
# Querying data for station: 231800
# No data found for this station.
# Querying data for station: 405810
# Querying data for station: 401824
# Querying data for station: 223801
# Querying data for station: 223802
# Querying data for station: 401823
# Querying data for station: 233801
# Querying data for station: 404210
# Querying data for station: 415226
# Querying data for station: 415257
# Querying data for station: 415260
# Querying data for station: 586065
# Querying data for station: 238802
# Querying data for station: 405720
# Querying data for station: 587117
# Querying data for station: 403217
# Querying data for station: 512217A
# No data found for this station.
# Querying data for station: 405241
# Querying data for station: 00001
# Querying data for station: 410998
# Querying data for station: ROCKLANDS
# Querying data for station: 236249
# Querying data for station: 234214
# No data found for this station.
# Querying data for station: 415264
# Querying data for station: 586184
# Querying data for station: 235237
# Querying data for station: 502214A
# No data found for this station.
# Querying data for station: 502253A
# No data found for this station.
# Querying data for station: 405234
# Querying data for station: 405306
# Querying data for station: 502302A
# No data found for this station.
# Querying data for station: 229833A
# Querying data for station: 405292
# Querying data for station: 215008
# Querying data for station: 086106
# Querying data for station: 586034
# No data found for this station.
# Querying data for station: 229825A
# Querying data for station: 231110A
# Querying data for station: 228378A
# Querying data for station: 229853A
# Querying data for station: 222219
# Querying data for station: 222013
# Querying data for station: 222026
# Querying data for station: 401210
# Querying data for station: 222209
# Querying data for station: 401231
# Querying data for station: 222023
# Querying data for station: 229855A
# Querying data for station: 228824A
# Querying data for station: 587051
# Querying data for station: 502294A
# No data found for this station.
# Querying data for station: 502225A
# No data found for this station.
# Querying data for station: 229109A
# Querying data for station: 407315
# Querying data for station: 230112A
# Querying data for station: 512222A
# No data found for this station.
# Querying data for station: 229247B
# Querying data for station: 405240
# Querying data for station: 229607A
# No data found for this station.
# Querying data for station: 229809
# No data found for this station.
# Querying data for station: 230202C
# Querying data for station: 405212
# Querying data for station: 587004
# Querying data for station: 586176
# Querying data for station: 237207
# Querying data for station: 230807A
# Querying data for station: 407808
# Querying data for station: 410999
# Querying data for station: WT650
# Querying data for station: 570931
# Querying data for station: 407809
# Querying data for station: 570909
# Querying data for station: 570987
# Querying data for station: 221055
# Querying data for station: 570942
# Querying data for station: 570944
# Querying data for station: 401220
# Querying data for station: 223213
# Querying data for station: 223202
# Querying data for station: 223214
# Querying data for station: 223208
# Querying data for station: 226216
# Querying data for station: 502276A
# No data found for this station.
# Querying data for station: 219006
# No data found for this station.
# Querying data for station: 219019
# No data found for this station.
# Querying data for station: 228201B
# Querying data for station: 228238A
# Querying data for station: 228224A
# Querying data for station: 586198
# Querying data for station: 085202
# Querying data for station: 410155
# Querying data for station: 404708
# No data found for this station.
# Querying data for station: 583034
# No data found for this station.
# Querying data for station: 585078
# No data found for this station.
# Querying data for station: 225231
# Querying data for station: 229856A
# Querying data for station: 235255
# Querying data for station: 585056
# Querying data for station: 225815A
# Querying data for station: 225814A
# Querying data for station: 229649A
# Querying data for station: 502215A
# No data found for this station.
# Querying data for station: 502252A
# No data found for this station.
# Querying data for station: 231231
# Querying data for station: 231231A
# Querying data for station: 587019
# Querying data for station: 401014
# Querying data for station: 401554
# Querying data for station: 086117
# Querying data for station: 512218A
# No data found for this station.
# Querying data for station: 502245A
# No data found for this station.
# Querying data for station: 226410
# Querying data for station: 226415
# Querying data for station: 226023
# No data found for this station.
# Querying data for station: 406273
# Querying data for station: 407222
# Querying data for station: 401007
# Querying data for station: 409056
# No data found for this station.
# Querying data for station: 218009
# No data found for this station.
# Querying data for station: 226246
# No data found for this station.
# Querying data for station: 00215
# Querying data for station: TAYLORS
# Querying data for station: 415608
# Querying data for station: 00081
# Querying data for station: 570968
# Querying data for station: TOOLONDO
# Querying data for station: 00184
# Querying data for station: 570902
# Querying data for station: sp-o11430
# Querying data for station: sp-o11454
# Querying data for station: 570813
# Querying data for station: 572028
# Querying data for station: 086271
# Querying data for station: 586019
# No data found for this station.
# Querying data for station: UPPERCOLIBAN
# Querying data for station: 570805
# Querying data for station: RE604
# Querying data for station: 502295A
# No data found for this station.
# Querying data for station: 401226
# Querying data for station: 235249
# Querying data for station: 407806
# Querying data for station: 088060
# Querying data for station: 588026
# Querying data for station: 221002
# No data found for this station.
# Querying data for station: 586146
# Querying data for station: 218010
# No data found for this station.
# Querying data for station: 502230A
# No data found for this station.
# Querying data for station: 586193
# Querying data for station: 233223
# Querying data for station: 412184
# No data found for this station.
# Querying data for station: 224201
# Querying data for station: 229608A
# Querying data for station: 415238
# Querying data for station: 412134
# Querying data for station: 229130A
# Querying data for station: 415801
# Querying data for station: 415800
# Querying data for station: 502263A
# No data found for this station.
# Querying data for station: 222004
# Querying data for station: 401016
# Querying data for station: 231708
# No data found for this station.
# Querying data for station: 231221A
# Querying data for station: 587030
# Querying data for station: 233232
# Querying data for station: 405291
# Querying data for station: 21210060
# No data found for this station.
# Querying data for station: 21210061
# No data found for this station.
# Querying data for station: 21210062
# No data found for this station.
# Querying data for station: 21210063
# No data found for this station.
# Querying data for station: 21210064
# No data found for this station.
# Querying data for station: 21210065
# No data found for this station.
# Querying data for station: 406235
# Querying data for station: 219062
# No data found for this station.
# Querying data for station: 410160
# Querying data for station: 415207
# Querying data for station: 415254
# No data found for this station.
# Querying data for station: 415256
# Querying data for station: 586051
# Querying data for station: 234201
# Querying data for station: 224206
# Querying data for station: 586085
# Querying data for station: 229215B
# Querying data for station: WS1002
# Querying data for station: 231817A
# Querying data for station: 233259
# Querying data for station: 412010
# Querying data for station: WARTOOK
# Querying data for station: 570981
# Querying data for station: 41000241
# Querying data for station: 570819
# No data found for this station.
# Querying data for station: RE750
# Querying data for station: RE851
# Querying data for station: ST703
# Querying data for station: 570822
# Querying data for station: 570948
# Querying data for station: 570824
# Querying data for station: RE704
# Querying data for station: 402204
# Querying data for station: 502247A
# No data found for this station.
# Querying data for station: 229406A
# Querying data for station: 086131
# Querying data for station: 586101
# Querying data for station: 502250A
# No data found for this station.
# Querying data for station: 229715A
# Querying data for station: 410574
# Querying data for station: 229200
# No data found for this station.
# Querying data for station: 229812
# No data found for this station.
# Querying data for station: 229270A
# Querying data for station: 229142A
# Querying data for station: 229621A
# Querying data for station: 229653A
# Querying data for station: 229143A
# Querying data for station: 229135A
# Querying data for station: 229102A
# Querying data for station: 229200B
# Querying data for station: 502249A
# No data found for this station.
# Querying data for station: 409700
# No data found for this station.
# Querying data for station: 415293
# Querying data for station: 405217
# No data found for this station.
# Querying data for station: 570941
# Querying data for station: 570978
# Querying data for station: sp-o10814
# Querying data for station: A2391075

# %%
conv_df = df.copy()
conv_df.set_index('Time', inplace=True)


pivot_df = df.pivot_table(index='Time', values='Value', columns='Station', aggfunc='first')


pivot_df.index = pd.to_datetime(pivot_df.index)



# Resample data into hourly bins and calculate the mean for each hour
resampled_df = pivot_df.resample(TIMESCALE[0].upper()).first()

# Show pivoted DataFrame
print(resampled_df)

resampled_df.to_csv(f'{OUTPUT_DOC}.csv', index=True)
# Out:
# Station                    00001  00004  00008  00009  00014  00015  00018  \
# Time
# 2010-01-31 00:00:00+10:00    0.2   10.4   37.0   12.5   None   None   10.4
# 2010-02-28 00:00:00+10:00   22.7  191.4  183.0  159.0   None   None  209.3
# 2010-03-31 00:00:00+10:00   66.4   67.6   93.6   53.0   None   None   87.6
# 2010-04-30 00:00:00+10:00  159.4   11.6  121.0    5.0   None   None   51.5
# 2010-05-31 00:00:00+10:00   57.8   75.4  164.8   61.5   None   None  146.4
# ...                          ...    ...    ...    ...    ...    ...    ...
# 2023-09-30 00:00:00+10:00   None   31.6  103.4   27.0   54.7   95.0   78.7
# 2023-10-31 00:00:00+10:00   None   60.2  287.0   83.4  205.1  296.2   76.5
# 2023-11-30 00:00:00+10:00   None  360.0  377.6  274.4  255.9  337.8  335.9
# 2023-12-31 00:00:00+10:00   None  267.0  354.2  280.2  122.7  167.2  249.0
# 2024-01-31 00:00:00+10:00   None   71.6  263.0  101.4   None  234.2  180.3
#
# Station                    00052  00072  00081  ... sp-o10298 sp-o10350  \
# Time                                            ...
# 2010-01-31 00:00:00+10:00   None   89.6   67.8  ...      73.9      11.6
# 2010-02-28 00:00:00+10:00   None   None  188.8  ...     124.6      58.2
# 2010-03-31 00:00:00+10:00   None   None   92.2  ...     103.4      59.0
# 2010-04-30 00:00:00+10:00   None   None  149.3  ...      67.2      73.8
# 2010-05-31 00:00:00+10:00   None   None  160.2  ...      51.4      47.8
# ...                          ...    ...    ...  ...       ...       ...
# 2023-09-30 00:00:00+10:00  102.9  136.0  113.5  ...      None       9.0
# 2023-10-31 00:00:00+10:00  206.4  374.6  288.7  ...      None      62.0
# 2023-11-30 00:00:00+10:00  252.4  398.3  318.0  ...      None      56.3
# 2023-12-31 00:00:00+10:00  243.2  258.2  268.9  ...      None      40.5
# 2024-01-31 00:00:00+10:00  277.6  223.9  172.1  ...      None     229.8
#
# Station                   sp-o10438 sp-o10606 sp-o10814 sp-o10926 sp-o10930  \
# Time
# 2010-01-31 00:00:00+10:00      18.5      21.1      15.1       1.4      32.3
# 2010-02-28 00:00:00+10:00      54.3      29.7     107.6      19.4      57.8
# 2010-03-31 00:00:00+10:00     156.2      85.0      69.4     124.7     126.2
# 2010-04-30 00:00:00+10:00      53.0      30.2      40.3      25.7     102.9
# 2010-05-31 00:00:00+10:00      67.2      39.6      60.7       0.0      60.1
# ...                             ...       ...       ...       ...       ...
# 2023-09-30 00:00:00+10:00      16.4       2.2       7.6      48.2      37.9
# 2023-10-31 00:00:00+10:00       5.0      28.2      65.2      93.6      17.6
# 2023-11-30 00:00:00+10:00      72.2      13.8      33.0      22.3      39.5
# 2023-12-31 00:00:00+10:00      62.9       2.6      51.1      54.3     128.7
# 2024-01-31 00:00:00+10:00      60.9      99.4     129.0     111.5      44.9
#
# Station                   sp-o11430 sp-o11454 sp-o11590
# Time
# 2010-01-31 00:00:00+10:00      29.5      22.9     104.8
# 2010-02-28 00:00:00+10:00      27.8      29.5     142.4
# 2010-03-31 00:00:00+10:00      61.0     103.2     166.0
# 2010-04-30 00:00:00+10:00      37.5      43.0     131.0
# 2010-05-31 00:00:00+10:00      65.0      41.0      75.4
# ...                             ...       ...       ...
# 2023-09-30 00:00:00+10:00       5.0       2.0      37.0
# 2023-10-31 00:00:00+10:00      48.0      29.2      31.7
# 2023-11-30 00:00:00+10:00      80.6      11.2     104.0
# 2023-12-31 00:00:00+10:00      37.5      10.6     123.0
# 2024-01-31 00:00:00+10:00     159.0      67.8     166.6
#
# [169 rows x 720 columns]
